# %% [markdown]
# # COGS 108 - Final Project (San Diego Pothole City)
#
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public, including the names of the authors.
#
# * [  ] YES - make available
# * [ X ] NO - keep private
#
# ## Link to video
# https://www.dropbox.com/scl/fi/4xbjt0vk7ijm58un5ieb2/group126cogs108.mov?rlkey=e66m2st5es3973payofgft2nt&st=tkj5v0xd&dl=0
#
# ## Abstract
#
# Our group decided to focus on street maintenance as an important infrastructure in San Diego as UCSD students by specifically relating pothole requests and city property costs to relate to the localities of neighborhoods and regulation on maintaining these infrastructures. This research investigates the relationship between street repair requests and city property costs in the span of 6 years from 2017 to 2022 while also seeing if there is a prediction on frequency of repairs by traffic volumes and costs of city property.
#
# By doing this, we break the research into different datasets to determine which data from each set can contribute to our findings to answer the research question. Our datasets include traffic volumes, street/pothole repair requests, and property costs. We did data wrangling, tidying up datasets, exploring different statistics in each dataset (i.e frequency of the same zipcode or street names, costs, density of traffic in specific neighborhoods in San Diego) as a way to describe different forms of data to understand the visualization as well as data analysis. Each dataset had specific columns that we kept in coordination of our analysis towards the research question.
#
# After creating our datasets from publicly available resources from San Diego county, we then conducted exploratory data analysis with our datasets. We first compared potholes versus prices using the scatterplots model and the OLS regression table, we see that the more potholes there is a slight decrease in cost of property. We then used choropleth maps to visualize the pothole repairs, traffic volumes aggregated by zipcode. WE see that a lot of pothole requests happen to be concentrated more central to north part of San Diego as opposed to traffic volume are more dense on the east side of San Diego county.
#
# From our findings of our analysis, we learned that traffic density or city property costs aren't the only factors affecting the frequency of pothole requests. Factors like weather are an aspect of the pothole repairs but doesn’t justify the sole factor as a way to predict where and how street repair requests will be sent.

# %% [markdown]
# ## Authors
#
# - Ynna Cate: Conceptualization, Analysis, Data curation, Visualization, Writing - original draft
# - Nicole Go: Software, Data curation, Data curation, Visualization, Writing - original draft
# - Jeric Olan: Background research, Data curation, Visualization, Writing - original draft
# - Abby Rapada: Visualization, Project administration, Data curation, Writing - review & editing, Video editing
# - Xinrui Lyu:

# %% [markdown]
# ## Research Question

# %% [markdown]
# Is there a relationship between street/pothole repair requests, traffic volumes, and city property costs in San Diego between the years of 2017 and 2022? Using the relationship seen in those 6 years, are we able to predict the frequency of pothole repair requests by observing the cost of city property and traffic volumes in San Diego?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# The prevalence of potholes in San Diego is a topic of frustration for many, if not most San Diegan drivers. Within the 2,800 miles of streets and roads in San Diego, there are over 40,000 potholes that are repaired every year. <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1). In San Diego, potholes most commonly arise when water seeps under pavement and weakens the integrity of the road. With the constant passage of traffic, the vibrations of vehicles driving over these weakened spots eventually break the pavement resulting in a new pothole. <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2). Thus, in order to reasonably predict the occurrence of potholes and the repair requests they garner, an understanding of the relationship between request frequency, weather patterns, and traffic volume must be considered. In addition, the resolution time of repair tickets may be predicted by patterns of economic growth of certain cities as well as prolonged wet periods in San Diego.
#
#
#
#
# Most of the previous work related to potholes relate to the detection of potholes and not the prediction of onset/complaint. Importantly, many of the works agree that weather and traffic patterns contribute to the risk of pothole creation. One such paper focuses its research on using machine learning and in-vehicle cameras to capture 2D images of potholes and their respective size <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3). Related to potholes, machine learning may also be used to predict Concrete Pavement Condition Index (CPCI). A study based in South Korea seeks for more effective road management by developing a way to accurately predict the rate of degradation of concrete pavement <a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4). Perhaps the most similar study based its work in pothole prediction based on pavement condition indicators. This article found that the formation of potholes are mostly unpredictable and due to a multitude of conditions and dominant defects such as surface cracking and the condition of the surrounding pavement <a name="cite_ref-5"></a>[<sup>5</sup>](#cite_note-5).
#
#
#
#
# Though these previous studies overall differ from our focus, they are nevertheless critical to our understanding of the risks of potholes as well as the importance of predictive action. They also offer more solution based literature that may only improve with the continuing development of machine learning. These works also highlight the intricacies of predicting infrastructure conditions. Thus, we acknowledge that our study is bound to many limitations and confounding factors as well as having an insufficient scale to consider many of the possible contributing factors to our question. For instance, given our present data, our focus is on pothole repair requests and not objective pothole frequency. Using repair requests as a proxy for pothole frequency has limitations in that it is not telling of pothole onset. Repeating requests may also be present. If provided a longer time-frame and sufficient resources, our current project may aim to consider more contributors to pothole formation as well as repair promptness.
#
#
#
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Street resurfacing and Pothole Repair. Street Resurfacing and Pothole Repair | City of San Diego Official Website. https://www.sandiego.gov/street-div/services/street-resurfacing-pothole-repair
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Road maintenance. County of San Diego. https://www.sandiegocounty.gov/content/sdc/dpw/roads/surface.html
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Ruseruka, C., Mwakalonge, J., Comert, G., Siuhi, S., NGENI, F., & Anderson, Q. (2023). Augmenting Roadway Safety with Machine Learning and Deep Learning: Pothole Detection and Dimension Estimation Using in-Vehicle Technologies. https://doi.org/10.2139/ssrn.4655731
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Lee, J.-H., Jung, D.-H., Lee, M.-S., & Jeon, S.-I. (2022, August 31). A feasibility study for the prediction of Concrete Pavement Condition index (CPCI) based on machine learning. MDPI. https://www.mdpi.com/2076-3417/12/17/8731
# 5. <a name="cite_note-5"></a> [^](#cite_ref-5) Pothole prediction based on machine learning and pavement 1. https://publications.aston.ac.uk/id/eprint/47761/1/Pothole_prediction_based_on_machine_learning_and_pavement_condition_indicators_AAM.pdf

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We predict a strong correlation between the number of potholes repair requests and traffic volume and city property costs in San Diego County. Property costs metrics include start dates, the cost of the lease, location, and type of lease (e.g. house rental, permit, agreement, etc.) Specifically, we predict that higher traffic volumes and higher property cost correlate with a greater frequency of pothole requests.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data overview
#
# - Dataset #1
#   - Dataset Name:
#     - Traffic Volumes
#   - Link to the dataset:
#     - https://data.sandiego.gov/datasets/traffic-volumes/
#   - Number of observations:
#     - 13690
#   - Number of variables:
#     - 10
#   - Variables most relevant to this project:
#     - street_name: The street vehicles were counted on
#     - limits: Cross streets vehicles were counted between
#     - total_count: Total count of vehicles traveling in all directions (north, south, east, west) in 24 hrs
#     - count_date: The date vehicles were counted
#   - Shortcomings this dataset has with respect to the project:
#     - This dataset's dates range from January 05, 2005 to Novemeber 22, 2022. This may limit the recency of the date we can look at for our predictions and not reflect patterns that may have emerged between then and the present.
#
# - Dataset #2
#   - Dataset Name:
#     - Prices
#   - Link to the dataset:
#     - https://seshat.datasd.org/city_owned_properties_leases/city_property_leases_datasd.csv
#   - Number of observations:
#     - 814
#   - Number of variables:
#     - 14
#   - Variables most relevant to this project:
#     - address_zip: Zip code of the lease
#     - cost_line_amt_USD: Amount of lease payments
#     - effective_date: date of lease effective
#     - sched_termination_date: scheduled date for the lease to be terminated
#   - Shortcomings this dataset has with respect to the project:
#     - This dataset doesn't encapsulate all of the properties within San Diego County.
#     - This dataset will be combined with traffic to optimize the chances of a pothole request being put in.
#
# - Dataset #3
#   - Dataset Name:
#     - Pothole Requests
#   - Link to the dataset:
#     - https://data.sandiego.gov/datasets/gid-pothole/
#   - Number of observations:
#     - 13690
#   - Number of variables:
#     - 10
#   - Variables most relevant to this project:
#     - street_name: The street vehicles were counted on
#     - limits: Cross streets vehicles were counted between
#     - total_count: Total count of vehicles traveling in all directions (north, south, east, west) in 24 hrs
#     - count_date: The date vehicles were counted
#   - Shortcomings this dataset has with respect to the project:
#     - This dataset's dates range from January 09, 2017 to May 12, 2026. January 09, 2017 serves as the minimum date we may use between all of our data sets. We may lose potential patterns that may have emerged before 2017.

# %%
# %load_ext autoreload
# %autoreload 2

# %pip install nbstripout
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Setup Code

import sys
sys.path.append('./modules') # this tells python where to look for modules to import

import get_data # this is where we get the function we need to download data

# replace the urls and filenames in this list with your actual datafiles
# yes you can use Google drive share links or whatever
# format is a list of dictionaries; 
# each dict has keys of 
#   'url' where the resource is located
#   'filename' for the local filename where it will be stored 
datafiles = [
    { 'url': 'https://raw.githubusercontent.com/frozenbabywipes/traffice-volumes-dataset/refs/heads/main/traffic_counts_datasd%20(1).csv', 'filename':'traffic_volumes.csv'},
    { 'url': 'https://seshat.datasd.org/city_owned_properties_leases/city_property_leases_datasd.csv', 'filename':'property-prices.csv'}
]

get_data.get_raw(datafiles,destination_directory='data/00-raw/')
# Out:
# Overall Download Progress:  50%|█████     | 1/2 [00:01<00:01,  1.36s/it]
# Successfully downloaded: traffic_volumes.csv
# Overall Download Progress: 100%|██████████| 2/2 [00:01<00:00,  1.10it/s]
# Successfully downloaded: property-prices.csv

# %% [markdown]
# **NOTE** The final report should not be overly long.  If this wrangling step is huge and complicated you should remove these sections from the final report and replace them with a statement like "To see the code responsible for wrangling the data see `01-DataCheckpoint.ipynb`. From here on we will simply load the processed data for further analysis"

# %% [markdown]
# ### Traffic Volumes in San Diego
#
# This dataset records vehicle counts on San Diego streets in 24 hr intervals (per day). According to Data San Diego (https://data.sandiego.gov/datasets/traffic-volumes/), the specific block segments seen in the data are representative of a larger segment on the same roadway.
#
# Metrics:
# - street_name / limits:
#     - Stored as strings. The frequency of street observations were dependent on city needs to analyze that given area.
# - total_count
#     - Stored as integers. Total count of vehicles traveling in all directions (north, south, east, west) in 24 hrs.
# - count_date
#     - Stored as strings. The date vehicles were counted.
#
# Concerns:
# - Some streets may be over or underrepresented which will require additional filtering of data when merging datasets
# - Vehicle counts is a vague description. It's unknown if vehicles were large, small, heavy, light, etc. which may affect our hypothesis (e.g. what if all the vehicles recorded were bikes?). Reasonable however, we may assume that a majority of counts were of cars.
# - Vehicle counts were not taken every day. There are gaps in recorded dates which may also leave gaps of observable comparisons between our datasets.

# %% [markdown]
# #### Import pandas + numpy + load dataset

# %%
import pandas as pd
import numpy as np

df_traf_vol = pd.read_csv('https://raw.githubusercontent.com/frozenbabywipes/traffice-volumes-dataset/refs/heads/main/traffic_counts_datasd%20(1).csv')

df_traf_vol
# Out:
#                 id street_name                limits northbound_count  \
# 0       01AV018207       01 AV         A ST - ASH ST            18010
# 1       01AV015210       01 AV         A ST - ASH ST            20060
# 2       01AV018213       01 AV         A ST - ASH ST            19597
# 3       01AV007721       01 AV         A ST - ASH ST            10640
# 4       01AV088812       01 AV     ASH ST - BEECH ST             2298
# ...            ...         ...                   ...              ...
# 13686  ZOOPL009205      ZOO PL  PARK BL - FLORIDA DR             2620
# 13687  ZOOPL013708      ZOO PL  PARK BL - FLORIDA DR             4790
# 13688  ZOOPL033011      ZOO PL  PARK BL - FLORIDA DR             2425
# 13689  ZOOPL112614      ZOO PL  PARK BL - FLORIDA DR             1935
# 13690  ZOOPL022018      ZOO PL  PARK BL - FLORIDA DR             3110
#
#        southbound_count  eastbound_count  westbound_count  total_count  \
# ...

# %% [markdown]
# #### Checking shape and columns

# %%
print(df_traf_vol.shape)
print(df_traf_vol.columns)
# Out:
# (13691, 10)
# Index(['id', 'street_name', 'limits', 'northbound_count', 'southbound_count',
#        'eastbound_count', 'westbound_count', 'total_count', 'file_no',
#        'date_count'],
#       dtype='str')

# %% [markdown]
# #### Drop unnecessary columns

# %%
df_traf_vol = df_traf_vol.drop(columns=['id','northbound_count', 'southbound_count', 'eastbound_count', 'westbound_count', 'file_no'])

df_traf_vol
# Out:
#       street_name                limits  total_count           date_count
# 0           01 AV         A ST - ASH ST        18010  2007-03-13 00:00:00
# 1           01 AV         A ST - ASH ST        20060  2010-03-18 00:00:00
# 2           01 AV         A ST - ASH ST        19597  2013-03-12 00:00:00
# 3           01 AV         A ST - ASH ST        10640  2021-03-10 00:00:00
# 4           01 AV     ASH ST - BEECH ST         2298  2012-12-11 00:00:00
# ...           ...                   ...          ...                  ...
# 13686      ZOO PL  PARK BL - FLORIDA DR         6300  2005-04-07 00:00:00
# 13687      ZOO PL  PARK BL - FLORIDA DR         9430  2008-03-20 00:00:00
# 13688      ZOO PL  PARK BL - FLORIDA DR         5595  2014-05-24 00:00:00
# 13689      ZOO PL  PARK BL - FLORIDA DR         4425  2014-12-16 00:00:00
# 13690      ZOO PL  PARK BL - FLORIDA DR         6274  2018-04-17 00:00:00
#
# [13691 rows x 4 columns]

# %% [markdown]
# #### Checking for missing data + Drop rows with any NaNs
# - Dropping all observations with any NaN entries as we need data from every column.

# %%
df_traf_vol = df_traf_vol.dropna()


# Outputs 2 rows with at least NaNs before removing null
null_rows = df_traf_vol.isnull().any(axis=1).sum()


print(null_rows)
# Out:
# 0

# %% [markdown]
# #### Exploring data

# %%
print('\nUnderstanding data types:')
print(df_traf_vol.dtypes)


print('\nMinimum total count:')
print(df_traf_vol['total_count'].min())


print('\nMaximum total count:')
print(df_traf_vol['total_count'].max())


print('\nOldest date in data:')
print(df_traf_vol['date_count'].min())


print('\nMost recent date in data:')
print(df_traf_vol['date_count'].max())


rows_with_zero = df_traf_vol[df_traf_vol['total_count'] == 0]
count_rows_with_zero = len(rows_with_zero)


print('\nRows that have a total count of 0:')
print(rows_with_zero)


print('\n# of rows that have a total count of 0:')
print(count_rows_with_zero)
# Out:
# Understanding data types:
# street_name      str
# limits           str
# total_count    int64
# date_count       str
# dtype: object
#
# Minimum total count:
# 0
#
# Maximum total count:
# 89090
#
# Oldest date in data:
# 2005-01-05 00:00:00
#
# Most recent date in data:
# 2022-11-22 00:00:00
#
# Rows that have a total count of 0:
#                  street_name                                limits  \
# 1204                   55 ST            HARDY AV - CANYON CREST DR
# 1572   ALLEY S/O EL CAJON BL                         67 ST - 68 ST
# 1829    AVENIDA PLAYA  PLAYA   PASEO OCASO DR - LA JOLLA SHORES DR
# 2474               BONAIR ST                 TYRAIN ST - DRAPER AV
# 2618       BROADWAY BROADWAY                          30 ST - F ST
# 3728              CHELSEA AV             CRYSTAL DR - SEA RIDGE DR
# 3731              CHELSEA AV          DOLPHIN PL - CAMINO COSTA PL
# 3734              CHELSEA ST             SEA RIDGE DR - CHELSEA AV
# ...

# %% [markdown]
# #### Removing outliers
# - Removing 30 observations that recorded 0 total vehicles within 24 hrs. This data seems unlikely unless there were prolonged street closures.

# %%
df_traf_vol = df_traf_vol[df_traf_vol['total_count'] != 0]


# verify that rows with outlier values are dropped
print('\nRows that have a total count of 0:')
print((df_traf_vol['total_count'] == 0).sum())


# checking for new minimum
print('\nNew minimum total count:')
print(df_traf_vol['total_count'].min())


# check how many observations counted 5 vehicles
rows_with_five = df_traf_vol[df_traf_vol['total_count'] == 5]
count_rows_with_five= len(rows_with_five)
print('\n# of rows that have a total count of 5:')
print(count_rows_with_five)
print('\nThis new minimum of 5 total vehicles counted for one day may account for construction of a road so it may be more plausible than a total count of 0')
# Out:
# Rows that have a total count of 0:
# 0
#
# New minimum total count:
# 5
#
# # of rows that have a total count of 5:
# 1
#
# This new minimum of 5 total vehicles counted for one day may account for construction of a road so it may be more plausible than a total count of 0

# %% [markdown]
# #### Filtering out irrelevent dates
# - We are only looking from January 09, 2017 (most recent oldest date in pothole dataset) to Novemeber 22, 2022 (oldest most recent date from traffic volume dataset)

# %%
df_traf_vol = df_traf_vol[df_traf_vol['date_count'] >= '2017-01-09']

# check new oldest date
df_traf_vol['date_count'].min()
# Out:
# '2017-01-11 00:00:00'

# %% [markdown]
# #### Clean + Tidy Traffic Volume Dataset

# %%
traffic_volume = df_traf_vol

traffic_volume
# Out:
#         street_name                         limits  total_count  \
# 3             01 AV                  A ST - ASH ST        10640
# 14            01 AV            BEECH ST - CEDAR ST        16482
# 38            01 AV        JUNIPER ST - KALMIA  ST         5842
# 43            01 AV         JUNIPER ST - KALMIA ST         5262
# 60            01 AV  PENNSYLVANIA AV - ROBINSON AV         7715
# ...             ...                            ...          ...
# 13675  YERBA STA DR     MESQUITE RD - MONTEZUMA RD         2561
# 13678       ZION AV         C LEE AV - ESTRELLA AV        10655
# 13684       ZION AV   MISSION GORGE RD - WARING RD        12239
# 13685        ZOO PL          PARK BL - FLORIDA  DR         5349
# 13690        ZOO PL           PARK BL - FLORIDA DR         6274
#
#                 date_count
# 3      2021-03-10 00:00:00
# 14     2020-03-12 00:00:00
# 38     2022-03-16 00:00:00
# 43     2018-03-13 00:00:00
# 60     2018-03-15 00:00:00
# ...                    ...
# ...

# %% [markdown]
# ### SD County Property Prices
#
# This dataset records information about San Diego City-owned property. Primarily, it provides data about rent amounts, start/end dates, leasees, and the type of properties in San Diego.
#
# Metrics:
# - address_zip:
#     - Zip code of the lease
# - cost_line_amt_USD:
#     - Amount of lease payments
# - effective_date:
#     - Date of lease effective
# - sched_termination_date:
#     - Scheduled date for the lease to be terminated
#
# Concerns:
# - This dataset doesn't encapsulate all of the properties within San Diego County.
# - Given that there are different start/end dates per properties, additional consideration + filtering must be done to decide what properties we want to include in our question's timeframe
# - Zip codes + prices may be revealing for certain property types (mostly residential) but we argue that this information is already accessible via sites like Zillow.
#
# See instructions above for Dataset #1.  Feel free to keep adding as many more datasets as you need.  Put each new dataset in its own section just like these.
#
# Lastly if you do have multiple datasets, add another section where you demonstrate how you will join, align, cross-reference or whatever to combine data from the different datasets
#
# Please note that you can always keep adding more datasets in the future if these datasets you turn in for the checkpoint aren't sufficient.  The goal here is demonstrate that you can obtain and wrangle data.  You are not tied down to only use what you turn in right now.

# %% [markdown]
# #### Import pandas + numpy + dataset upload

# %%
## YOUR CODE TO LOAD/CLEAN/TIDY/WRANGLE THE DATA GOES HERE
import pandas as pd
import numpy as np

prices = pd.read_csv('https://seshat.datasd.org/city_owned_properties_leases/city_property_leases_datasd.csv')
prices
# Out:
#     site_code                                lessee_name  \
# 0      A001WR                               NEAL, ROBERT
# 1      A001WR             SAN DIEGUITO RIVER PARK JPA/15
# 2      A007WW                       PACIFIC TELEPHONE/01
# 3       ADMIN              AG ESSENTIAL HOUSING CA 2, LP
# 4       ADMIN                WESTFIELD CORPORATION, INC.
# ..        ...                                        ...
# 811    Z715PM             SD METROPOLITAN TRANSIT SYSTEM
# 812    Z715PM                         STATE OF CA/CHP/03
# 813    Z715PM          US CUSTOMS & BORDER PROTECTION/05
# 814    Z719PM  COUNTY OF SAN DIEGO/12 TIJUANA RIVER PARK
# 815    Z728PM            INTERCAM FINANCIAL SERVICES INC
#
#                       lessee_company                     lessee_DBA  \
# 0                       NEAL, ROBERT                            NaN
# 1        SAN DIEGUITO RIVER PARK JPA                            NaN
# 2               PACIFIC TELEPHONE/01                           AT&T
# ...

# %% [markdown]
# #### Checking Column Names and Shape

# %%
print(prices.columns)
print(prices.shape)
# Out:
# Index(['site_code', 'lessee_name', 'lessee_company', 'lessee_DBA',
#        'address_zip', 'lease_record_type', 'lease_description', 'lease_status',
#        'lease_location_name', 'nonprofit_lessee', 'date_effective',
#        'date_sched_termination', 'rent_code', 'cost_line_amt_USD'],
#       dtype='str')
# (816, 14)

# %% [markdown]
# #### Drop Unneeded Columns

# %%
prices = prices.drop(columns=['lessee_name', 'lessee_company', 'lessee_DBA'])

# %% [markdown]
# #### Drop Rows with Data Missing Under Cost Column

# %%
prices = prices.dropna(subset=['cost_line_amt_USD'])

prices
# Out:
#     site_code address_zip lease_record_type  \
# 4       ADMIN       13212         Agreement
# 5       ADMIN       92101             Lease
# 6        BLDG  92103-1946             Lease
# 8      C601WR  92025-2301             Lease
# 12     C701P2       92110            Permit
# ..        ...         ...               ...
# 809    Z706RS         NaN            Permit
# 810    Z706RS       92101             Lease
# 811    Z715PM       92101         Agreement
# 812    Z715PM  95798-9052             Lease
# 815    Z728PM       92173            Permit
#
#                                      lease_description lease_status  \
# 4                                      SHOPPING CENTER       Normal
# 5                            TRANSITIONAL HOUSING 5550       Normal
# 6                                    CHILD CARE CENTER          MTM
# 8                                    PEDESTRIAN BRIDGE       Normal
# 12   OPERATION AND MAINTENANCE OF STATE HISTORICAL ...    Held Over
# ...

# %% [markdown]
# #### Keep Data within a Timeframe

# %%
prices['date_effective'] = pd.to_datetime(prices['date_effective'], errors='coerce')

prices = prices[prices['date_effective'].between('2017-01-09', '2026-05-12')]

prices['date_effective'].min()

print(prices)
# Out:
#     site_code address_zip lease_record_type  \
# 5       ADMIN       92101             Lease
# 15     C701WW       92025             Lease
# 21     C701WW  92105-1607         Agreement
# 57     C701WW  92261-4563             Lease
# 70       CITY       92127             Lease
# ..        ...         ...               ...
# 735    Y802PA       90025         Agreement
# 803    Z702PM       92173         Agreement
# 805    Z702PM       92868         Agreement
# 806    Z702PM       92173         Agreement
# 815    Z728PM       92173            Permit
#
#                                      lease_description lease_status  \
# 5                            TRANSITIONAL HOUSING 5550       Normal
# 15                            ORGANIC ROW CROP FARMING    Held Over
# 21                                         FRUIT TREES       Normal
# 57                                  GROW & HARVEST SOD       Normal
# 70   Renting warehouse for Police property and evid...     Extended
# ...

# %% [markdown]
# #### Drop Rows without Zip Code

# %%
prices = prices.dropna(subset=['address_zip'])

prices
# Out:
#     site_code address_zip lease_record_type  \
# 5       ADMIN       92101             Lease
# 15     C701WW       92025             Lease
# 21     C701WW  92105-1607         Agreement
# 57     C701WW  92261-4563             Lease
# 70       CITY       92127             Lease
# ..        ...         ...               ...
# 735    Y802PA       90025         Agreement
# 803    Z702PM       92173         Agreement
# 805    Z702PM       92868         Agreement
# 806    Z702PM       92173         Agreement
# 815    Z728PM       92173            Permit
#
#                                      lease_description lease_status  \
# 5                            TRANSITIONAL HOUSING 5550       Normal
# 15                            ORGANIC ROW CROP FARMING    Held Over
# 21                                         FRUIT TREES       Normal
# 57                                  GROW & HARVEST SOD       Normal
# 70   Renting warehouse for Police property and evid...     Extended
# ...

# %% [markdown]
# #### Sort Data by Zip Code

# %%
prices = prices.sort_values(by='address_zip')

prices
# Out:
#     site_code address_zip lease_record_type             lease_description  \
# 661    STREET       07921            Permit      COMMUNICATIONS EQUIPMENT
# 209    L301LB       07921             Lease      COMMUNICATIONS EQUIPMENT
# 662    STREET       07921            Permit       COMUNICATIONS EQUIPMENT
# 581    S203WM       07921             Lease      COMMUNICATIONS EQUIPMENT
# 660    STREET       07921            Permit        COMMUNICATIONS/TELECOM
# ..        ...         ...               ...                           ...
# 333    N508PA      97759
#              Lease                        HANGAR
# 719    Y603RD       98006           License      COMMUNICATIONS EQUIPMENT
# 702    T706WM       98006             Lease     COMMUNICATIONS EQUIPMENT
# 419    O802RD       98006             Lease      COMMUNICATIONS EQUIPMENT
# 134    E901PM  98115-6349            Permit  RADIO TRANSMITTING/RECEIVING
#
#     lease_status                     lease_location_name  nonprofit_lessee  \
# ...

# %% [markdown]
# ### Pothole Requests

# %% [markdown]
# This ongoing dataset documents pothole report/fix requests within San Diego. These repair requests are received by the 'Get It Done' program: San Diego's official reporting system for non-emergency issues (e.g. illegal dumping, parking issues, graffiti, etc). The dataset includes information about the street address the repair was request for, the date of the request, user-submitted descriptions of their complaint, etc.
#
# Metrics: (descriptions taken from https://data.sandiego.gov/datasets/get-it-done-potholes/)
# - date_requested:
#     - Stored as a datetime. The date and time when the service request was made.
# - service_name:
#     - Stored as a string. A classification of the type of service to be performed.
# - status:
#     - Stored as a string. The current state of the service request.
# - street_address:
#     - Stored as a string. Street address for request location.
# - zipcode:
#     - Stored as a string. ZIP code for request location.
#
# Concerns:
# - Some requests may be duplicate requests about the same complaint thus inflating its representation in the analysis.

# %% [markdown]
# #### Load dataset

# %%
df_potholes = pd.read_csv('https://raw.githubusercontent.com/frozenbabywipes/traffice-volumes-dataset/refs/heads/main/get_it_done_pothole_requests_datasd%20(1).csv')

df_potholes
# Out:
#         service_request_id  service_request_parent_id  \
# 0                   131444                        NaN
# 1                  2403110                  2401124.0
# 2                  2403347                  2403345.0
# 3                  2406519                  2401124.0
# 4                  2418337                  2418290.0
# ...                    ...                        ...
# 100575             5715656                        NaN
# 100576             5715691                        NaN
# 100577             5715763                        NaN
# 100578             5715810                        NaN
# 100579             5715813                        NaN
#
#         sap_notification_number       date_requested  case_age_days  \
# 0                  4.030010e+10  2017-01-09T16:22:00         1738.0
# 1                           NaN  2018-09-18T14:39:00          930.0
# 2                           NaN  2018-09-18T18:27:00         1130.0
# ...

# %% [markdown]
# #### Checking shape and columns

# %%
print(df_potholes.shape)
print(df_potholes.columns)
# Out:
# (100580, 23)
# Index(['service_request_id', 'service_request_parent_id',
#        'sap_notification_number', 'date_requested', 'case_age_days',
#        'case_record_type', 'service_name', 'service_name_detail',
#        'date_closed', 'status', 'lat', 'lng', 'street_address', 'zipcode',
#        'council_district', 'comm_plan_code', 'comm_plan_name', 'park_name',
#        'case_origin', 'referred', 'iamfloc', 'floc', 'public_description'],
#       dtype='str')

# %% [markdown]
# #### Dropping irrelevant variables

# %%
df_potholes = df_potholes.drop(columns=['service_request_id', 'service_request_parent_id', 'sap_notification_number', 'case_age_days', 'case_record_type', 'service_name_detail', 'date_closed', 'lat', 'lng', 'council_district', 'comm_plan_code', 'comm_plan_name', 'park_name',
       'case_origin', 'referred', 'iamfloc', 'floc', 'public_description'])

df_potholes
# Out:
#              date_requested service_name      status  \
# 0       2017-01-09T16:22:00      Pothole      Closed
# 1       2018-09-18T14:39:00      Pothole      Closed
# 2       2018-09-18T18:27:00      Pothole      Closed
# 3       2018-09-22T10:54:00      Pothole      Closed
# 4       2018-10-08T14:15:00      Pothole      Closed
# ...                     ...          ...         ...
# 100575  2026-05-12T18:23:00      Pothole  In Process
# 100576  2026-05-12T18:57:00      Pothole  In Process
# 100577  2026-05-12T20:16:00      Pothole      Closed
# 100578  2026-05-12T22:00:00      Pothole  In Process
# 100579  2026-05-12T22:12:00      Pothole      Closed
#
#                                            street_address  zipcode
# 0       2869 Barnard Street, San Diego, CA, United States  92110.0
# 1                                       COLLEGE AV, 92115  92120.0
# 2            1847 Sherbrooke St, San Diego, CA 92139, USA  92139.0
# ...

# %% [markdown]
# #### Checking for missing data

# %%
# Outputs 908 rows (899 with NaN zipcodes and 9 with NaN addresses) before removing null
null_rows = df_potholes.isnull().any(axis=1).sum()

print(df_potholes.isnull().sum())
print(null_rows)

print('\nWhat do null zips look like')
zip_null_ex = df_potholes[df_potholes['zipcode'].isnull()].head()
print(zip_null_ex)

print('\nWhat do null addresses look like')
address_null_ex = df_potholes[df_potholes['street_address'].isnull()].head()
print(address_null_ex)
# Out:
# date_requested      0
# service_name        0
# status              0
# street_address      9
# zipcode           899
# dtype: int64
# 908
#
# What do null zips look like
#            date_requested service_name  status  \
# 434   2020-12-29T16:32:00      Pothole  Closed
# 714   2021-01-07T17:29:00      Pothole  Closed
# 1568  2021-02-02T10:53:00      Pothole  Closed
# 1911  2021-02-10T10:01:00      Pothole  Closed
# 2285  2021-02-18T14:15:00      Pothole  Closed
#
#                                       street_address  zipcode
# 434   8333 Calle Del Cielo, San Diego, Ca 92037, Usa      NaN
# 714       3023 Lincoln Ave, San Diego, CA 92104, USA      NaN
# 1568   9878 Mira Mesa Blvd, San Diego, Ca 92131, Usa      NaN
# 1911                             6430 INYO ST, 92139      NaN
# 2285    Camino De La Reina, San Diego, CA 92108, USA      NaN
#
# What do null addresses look like
#             date_requested service_name  status street_address  zipcode
# ...

# %% [markdown]
# #### Drop rows with any NaNs
# - Dropping all observations with empty address or zip as we potentially need address and zip code data.

# %%
df_potholes = df_potholes.dropna()

null_rows = df_potholes.isnull().any(axis=1).sum()

print(null_rows)
# Out:
# 0

# %% [markdown]
# #### Exploring data

# %%
print('\nUnderstanding data types:')
print(df_potholes.dtypes)

#make sure uniform datetime format
df_potholes['date_requested'] = pd.to_datetime(df_potholes['date_requested'])

print('\nOldest date in data:')
print(df_potholes['date_requested'].min())

print('\nMost recent date in data:')
print(df_potholes['date_requested'].max())

print('\nAre there any requests that are not potholes?')
print(df_potholes['service_name'].unique())
# Out:
# Understanding data types:
# date_requested        str
# service_name          str
# status                str
# street_address        str
# zipcode           float64
# dtype: object
#
# Oldest date in data:
# 2017-01-09 16:22:00
#
# Most recent date in data:
# 2026-05-12 22:12:00
#
# Are there any requests that are not potholes?
# <StringArray>
# ['Pothole']
# Length: 1, dtype: str

# %% [markdown]
# #### Filtering out irrelevent dates
# - We are only looking from January 09, 2017 (most recent oldest date in pothole dataset) to Novemeber 22, 2022 (oldest most recent date from traffic volume dataset)

# %%
df_potholes = df_potholes[df_potholes['date_requested'] <= '2022-11-22']

# check new most recent date
df_potholes['date_requested'].max()
# Out:
# Timestamp('2022-11-21 20:02:00')

# %% [markdown]
# #### Clean + Tidy Pothole Dataset

# %%
potholes = df_potholes

potholes
# Out:
#            date_requested service_name  status  \
# 0     2017-01-09 16:22:00      Pothole  Closed
# 1     2018-09-18 14:39:00      Pothole  Closed
# 2     2018-09-18 18:27:00      Pothole  Closed
# 3     2018-09-22 10:54:00      Pothole  Closed
# 4     2018-10-08 14:15:00      Pothole  Closed
# ...                   ...          ...     ...
# 27283 2022-11-21 17:52:00      Pothole  Closed
# 27284 2022-11-21 19:04:00      Pothole  Closed
# 27285 2022-11-21 19:19:00      Pothole  Closed
# 27286 2022-11-21 20:02:00      Pothole  Closed
# 27287 2022-11-21 20:02:00      Pothole  Closed
#
#                                           street_address  zipcode
# 0      2869 Barnard Street, San Diego, CA, United States  92110.0
# 1                                      COLLEGE AV, 92115  92120.0
# 2           1847 Sherbrooke St, San Diego, CA 92139, USA  92139.0
# 3             5661 College Ave, San Diego, CA 92120, USA  92120.0
# ...

# %% [markdown]
# ### Combining Lease and Pothole

# %% [markdown]
# #### Keeping Residential Leases

# %%
prices['lease_description'].unique()
# Out:
# <StringArray>
# [       'COMMUNICATIONS EQUIPMENT',         'COMUNICATIONS EQUIPMENT',
#           'COMMUNICATIONS/TELECOM',    'TELECOMMUNICATIONS EQUIPMENT',
#          'COMMUNICATIONS FACILITY',         'COMMUNICATION EQUIPMENT',
#                 'TELECOM FACILITY', 'COMMUNICATIONS TELECOM FACILITY',
#     'OPTICAL REPEATERS & ANTENNAS',    'HOTEL, SPA, RESTAURANT, DOCK',
#  ...
#        'ROWING & STORAGE FACILITY',                         'PARKING',
#                       'OFFICE USE',     'MOBILE HOT DOG VENDING CART',
#        'Flattop West 3F Hangar 5B',              'GROW & HARVEST SOD',
#       'ABOVE GROUND PROPANE TANKS',                    'AUTO PARKING',
#        'COMMUNICATIONS EQUIPMENT ',    'RADIO TRANSMITTING/RECEIVING']
# Length: 155, dtype: str

# %%
prices = prices[
    prices['lease_description'].str.contains(
        'RESIDENTIAL|RESIDENCE|APARTMENT|HOUSING|RENT',
        case=False,
        na=False
    )
]
print(prices)
# Out:
#     site_code address_zip lease_record_type  \
# 191    J603WR       66223            Permit
# 735    Y802PA       90025         Agreement
# 5       ADMIN       92101             Lease
# 78       CITY  92101-1507             Lease
# 477    Q309PM       92110             Lease
# 480    Q319PM  92111-1209             Lease
# 481    Q319PM  92111-1209             Lease
# 408    O206PM  92111-1209             Lease
# 605    S511PM  92114-4213             Lease
# 348    N508PA       92123         Agreement
# 70       CITY       92127             Lease
# 726    Y802PA       92154             Lease
# 725    Y802PA       92154             Lease
#
#                                      lease_description lease_status  \
# 191          BOAT RENTAL, MERCHANDISE & PERMIT SALES.        Normal
# 735             RENT OFFSET AGREEMENT, PHASE 2 PARCELS       Normal
# 5                            TRANSITIONAL HOUSING 5550       Normal
# ...

# %% [markdown]
# #### Combining the datasets by matching location

# %%
potholes = df_potholes.copy()

potholes = potholes.rename(columns={'zipcode': 'address_zip'})

potholes['address_zip'] = potholes['address_zip'].astype(str)
potholes['address_zip'] = potholes['address_zip'].str.replace(r'\.0$', '', regex=True)

# %%
potholes = potholes.rename(columns={
    'zipcode': 'address_zip'
})

location_match = prices.merge(potholes, on='address_zip', how='inner')

location_match
# Out:
#      site_code address_zip lease_record_type  \
# 0        ADMIN       92101             Lease
# 1        ADMIN       92101             Lease
# 2        ADMIN       92101             Lease
# 3        ADMIN       92101             Lease
# 4        ADMIN       92101             Lease
# ...        ...         ...               ...
# 4491    Y802PA       92154             Lease
# 4492    Y802PA       92154             Lease
# 4493    Y802PA       92154             Lease
# 4494    Y802PA       92154             Lease
# 4495    Y802PA       92154             Lease
#
#                                       lease_description lease_status  \
# 0                             TRANSITIONAL HOUSING 5550       Normal
# 1                             TRANSITIONAL HOUSING 5550       Normal
# 2                             TRANSITIONAL HOUSING 5550       Normal
# 3                             TRANSITIONAL HOUSING 5550       Normal
# 4                             TRANSITIONAL HOUSING 5550       Normal
# ...

# %% [markdown]
# ### Seeing the Pothole Request Count per Lease

# %%
location_match['pothole_count'] = 1
combined_lease_pothole = (
    location_match
    .groupby(['site_code', 'address_zip', 'cost_line_amt_USD'])['pothole_count']
    .sum()
    .reset_index()
)

combined_lease_pothole
# Out:
#   site_code address_zip  cost_line_amt_USD  pothole_count
# 0     ADMIN       92101             402.00           1233
# 1      CITY       92127           14529.00            218
# 2    N508PA       92123             480.00            648
# 3    Q309PM       92110           32586.80           1007
# 4    Y802PA       92154            3627.29            695
# 5    Y802PA       92154           17367.00            695

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# Instructions: REPLACE the contents of this cell with your work, including any updates to recover points lost in your EDA feedback
#
# **NOTE** The final report should not be overly long.  If this EDA step is huge and complicated  and you went down a lot of dead ends, then you should do something about that.  Some options...
#
# 1) remove any EDA you later decided was unecessary side quest.
# 2) if the code to EDA is very long (in either lines or in time to compute) make sure you write out images of the EDA into `results/` and reload them as images here instead of recalculating it. And make a statement here like "To see the code responsible for EDA analyses see `02-EDACheckpoint.ipynb`."

# %% [markdown]
# ### Section 1 of EDA - Scatterplots
#
# To see which pairing of datasets would best help our hypothesis. Based on the combined dataset, the best comparison would be the Prices vs. Pothole Request.

# %% [markdown]
# ##### Import Matplotlib and sklearn

# %%
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %% [markdown]
# ##### Make a Scatterplot Function

# %%
def scatter_plot_trend(df, x_col, y_col):

    X = df[x_col]
    y = df[y_col]

    X_const = sm.add_constant(X)

    model = sm.OLS(y, X_const).fit()

    y_pred = model.predict(X_const)
   
    sorted_idx = np.argsort(X)

    X_sorted = X.iloc[sorted_idx]
    y_pred_sorted = y_pred.iloc[sorted_idx]

    plt.scatter(X, y)

    plt.plot(X_sorted, y_pred_sorted)

    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.title(f'{y_col} vs {x_col}')

    plt.show()

    return model

# %% [markdown]
# ##### Pothole Request vs. Prices

# %%
cost_v_pothole = scatter_plot_trend(combined_lease_pothole, 'cost_line_amt_USD', 'pothole_count')

# %% [markdown]
# ##### OLS Regression Table

# %%
print(cost_v_pothole.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          pothole_count   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.250
# Method:                 Least Squares   F-statistic:                 0.0008506
# Date:                Fri, 12 Jun 2026   Prob (F-statistic):              0.978
# Time:                        11:55:53   Log-Likelihood:                -43.046
# No. Observations:                   6   AIC:                             90.09
# Df Residuals:                       4   BIC:                             89.68
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const               753.9353    223.255      3.377      0.028     134.079    1373.791
# ...

# %% [markdown]
# ### Section 2 of EDA - Choropleth Maps

# %% [markdown]
# #### Install and import necessary libraries

# %%
# %pip install geopandas
# %pip install matplotlib

import geopandas as gpd
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Getting shapefile

# %%
zips = gpd.read_file('/Users/jeric/Documents/GitHub/Group-SP26-126/tl_2022_us_zcta520/tl_2022_us_zcta520.shp')
     

zips = zips.rename(columns={'ZCTA5CE20': 'zip'})

zips_sd = zips[
    zips['zip'].str.startswith(('920', '921'))
]

zips_sd
# Out:
#          zip GEOID20 CLASSFP20 MTFCC20 FUNCSTAT20    ALAND20  AWATER20  \
# 28315  92140   92140        B5   G6350          S    1386034     32140
# 28374  92093   92093        B5   G6350          S    2302505         0
# 28375  92161   92161        B5   G6350          S     227268         0
# 28379  92154   92154        B5   G6350          S  132874106   1633995
# 28389  92179   92179        B5   G6350          S     647809         0
# ...      ...     ...       ...     ...        ...        ...       ...
# 29923  92102   92102        B5   G6350          S   11630850         0
# 29948  92126   92126        B5   G6350          S   30008698         0
# 29965  92135   92135        B5   G6350          S    1089521         0
# 29981  92008   92008        B5   G6350          S   26937835   3726477
# 29985  92070   92070        B5   G6350          S  335183516  12660991
#
#         INTPTLAT20    INTPTLON20  \
# 28315  +32.7412792  -117.1977143
# 28374  +32.8821184  -117.2370825
# ...

# %% [markdown]
# ### Potholes

# %% [markdown]
# #### Grouping by zipcode

# %%
pothole_density = (
    potholes.groupby('address_zip').size().reset_index(name='count')
)

pothole_density
# Out:
#    address_zip  count
# 0        91911      1
# 1        91942      2
# 2        91945      3
# 3        92014    287
# 4        92025     27
# 5        92027      2
# 6        92029      1
# 7        92037   1402
# 8        92064      1
# 9        92067      1
# 10       92071     18
# 11       92075     18
# 12       92093    169
# 13       92101   1233
# 14       92102    761
# 15       92103   1334
# 16       92104   1416
# 17       92105   1059
# 18       92106    380
# 19       92107    273
# 20       92108    635
# 21       92109    992
# 22       92110   1007
# 23       92111   1592
# 24       92113    570
# 25       92114    986
# 26       92115   1389
# 27       92116    626
# 28       92117   1673
# 29       92119    494
# 30       92120    896
# 31       92121    718
# 32       92122    328
# 33       92123    648
# 34       92124    274
# 35       92126   1740
# 36       92127    218
# 37       92128   1293
# 38       92129    563
# 39       92130    280
# ...

# %% [markdown]
# #### Joining shapefile and pothole dataset

# %%
# making sure both zipcode columns are strings
pothole_density['address_zip'] = pothole_density['address_zip'].astype(str)
zips_sd['zip'] = zips_sd['zip'].astype(str)

ph_shapefile_df = zips_sd.merge(
    pothole_density,
    left_on='zip',
    right_on='address_zip',
    how='left'
)

# %% [markdown]
# #### Pothole Choropleth Plot

# %%
fig, ax = plt.subplots(figsize=(11,11))

ph_shapefile_df.plot(
    column = 'count',
    cmap = 'Reds',
    legend = True,
    linewidth = 0.3,
    edgecolor = 'black',
    ax = ax
)

ax.set_title('Pothole Repair Request Density by ZIP Code from 2017-2022')
ax.axis('off')
# Out:
# (np.float64(-117.3072149),
#  np.float64(-116.8187731),
#  np.float64(32.50149355),
#  np.float64(33.23366345))

# %% [markdown]
# ### Prices

# %% [markdown]
# #### Grouping by zipcode

# %%
prices_expense = (
    prices.groupby('address_zip')['cost_line_amt_USD'].mean().reset_index(name='average_prop_cost')
)

prices_expense
# Out:
#   address_zip  average_prop_cost
# 0       66223           5239.380
# 1       90025          20833.340
# 2       92101            402.000
# 3  92101-1507           5464.000
# 4       92110          32586.800
# 5  92111-1209          13338.000
# 6  92114-4213            295.000
# 7       92123            480.000
# 8       92127          14529.000
# 9       92154          10497.145

# %% [markdown]
# ### Traffic

# %% [markdown]
# ##### Imports for Geospatial Maps

# %%
import geopandas as gpd
import libpysal

# %% [markdown]
# ##### Read San Diego Shapefile

# %%
sd_data = gpd.read_file('data/00-raw/tl_2025_06073_roads.shp')

# %% [markdown]
# ##### Match Street Name Format between Dataframes

# %%
#ChatGPT: help renaming and aligning the street names
sd_data['clean_street'] = sd_data['FULLNAME'].astype(str).str.strip().str.upper()
traffic_volume['clean_street'] = traffic_volume['street_name'].astype(str).str.strip().str.upper()

replacements = {
    r'\b01\b': '1ST', r'\b02\b': '2ND', r'\b03\b': '3RD', r'\b04\b': '4TH', r'\b05\b': '5TH',
    r'\b06\b': '6TH', r'\b07\b': '7TH', r'\b08\b': '8TH', r'\b09\b': '9TH',
    r'\bAV\b': 'AVE', r'\bPL\b': 'PL', r'\bDR\b': 'DR', r'\bLN\b': 'LN', r'\bRD\b': 'RD'
}
for standard, correct in replacements.items():
    traffic_volume['clean_street'] = traffic_volume['clean_street'].str.replace(standard, correct, regex=True)

# %% [markdown]
# ##### Convert Street Names to Zipcodes

# %%
roads_zipcode = gpd.sjoin(sd_data, zips, how="left", predicate="within")
# Out:
# /var/folders/vq/d72ctr9s7194j3hs00m2fphc0000gn/T/ipykernel_26839/2035673954.py:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4269
#
#   roads_zipcode = gpd.sjoin(sd_data, zips, how="left", predicate="within")

# %% [markdown]
# ##### Apply Zipcodes to Traffic DataFrame

# %%
#ChatGPT: help converting to zipcodes
traffic_street = traffic_volume.groupby('clean_street')['total_count'].mean().reset_index()
roads_traffic_merged = roads_zipcode.merge(traffic_street, on='clean_street', how='inner')

# %% [markdown]
# ##### Group by Zipcode in Traffic Dataframe (use Zipcode Dataframe for conversion and boundaries)

# %%
traffic_by_zip = roads_traffic_merged.groupby('zip')['total_count'].mean().reset_index()
final_zip_map = zips.merge(traffic_by_zip, on='zip', how='inner')

# %% [markdown]
# ##### Plot Choropleth

# %%
fig, ax = plt.subplots(1, 1, figsize=(14, 10))

final_zip_map.plot(
    column='total_count',    
    cmap = 'Reds',
    legend = True,
    linewidth = 0.3,
    edgecolor = 'black',
    ax = ax
)

plt.title("San Diego Traffic Volumes Aggregated by Zip Code Area")
plt.show()

# %% [markdown]
# ### Analyses Part 1: Correlation Maps
#
# To see the correlation and p-value between our main 3 variables: pothole count, lease cost, and traffic count

# %%
from scipy.stats import pearsonr

corr, p = pearsonr(combined_lease_pothole['pothole_count'],
                   combined_lease_pothole['cost_line_amt_USD'])

print("Correlation:", corr)
print("p-value:", p)
# Out:
# Correlation: -0.014580991738306875
# p-value: 0.9781300623907474

# %%
import statsmodels.api as sm

X = combined_lease_pothole[['cost_line_amt_USD', 'pothole_count']]
X = sm.add_constant(X)

y = combined_lease_pothole['pothole_count']

model = sm.OLS(y, X).fit()

print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:          pothole_count   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 3.269e+29
# Date:                Fri, 12 Jun 2026   Prob (F-statistic):           9.83e-45
# Time:                        11:55:57   Log-Likelihood:                 159.62
# No. Observations:                   6   AIC:                            -313.2
# Df Residuals:                       3   BIC:                            -313.9
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# const              5.684e-14   1.08e-12      0.052      0.961   -3.39e-12    3.51e-12
# ...

# %%
# %pip install seaborn

import seaborn as sns
import matplotlib.pyplot as plt

corr_matrix = combined_lease_pothole.corr(numeric_only=True)

plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title("Correlation Heatmap")
plt.show()
sns.heatmap(
    combined_lease_pothole[['cost_line_amt_USD','pothole_count']].corr(),
    annot=True,
    cmap='coolwarm',
    center=0
)
plt.show()
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Analyses Part 2: Prediction Model

# %%
potholes['year'] = pd.to_datetime(
    potholes['date_requested']
).dt.year

potholes = potholes.rename(columns={'address_zip': 'zip'})

pothole_req_counts = (
    potholes.groupby(['zip', 'year'])
    .size()
    .reset_index(name = 'pothole_req_count')
)

pothole_req_counts
# Out:
#        zip  year  pothole_req_count
# 0    91911  2021                  1
# 1    91942  2021                  1
# 2    91942  2022                  1
# 3    91945  2021                  3
# 4    92014  2020                  3
# ..     ...   ...                ...
# 166  92173  2021                105
# 167  92173  2022                 81
# 168  92182  2020                  1
# 169  92182  2021                 17
# 170  92182  2022                  4
#
# [171 rows x 3 columns]

# %%
# set up for traffic predictor) ChatGPT helped add dates back to our dataframe with the zipcodes

traffic_volume['year'] = pd.to_datetime(
    traffic_volume['date_count']
).dt.year

traffic_street = traffic_volume.groupby(
    'clean_street'
)['total_count'].mean().reset_index()

traffic_street_year = (
    traffic_volume
    .groupby(['clean_street', 'year'])['total_count']
    .mean()
    .reset_index()
)

roads_traffic_year = roads_zipcode.merge(
    traffic_street_year,
    on='clean_street',
    how='inner'
)

roads_traffic_year = roads_traffic_year.rename(columns={'total_count': 'traffic_count_avg'})

traffic_zip_year = (
    roads_traffic_year
    .groupby(['zip', 'year'])['traffic_count_avg']
    .mean()
    .reset_index()
)


traffic_zip_year
# Out:
#        zip  year  traffic_count_avg
# 0    91901  2021       20435.000000
# 1    91902  2017        7685.000000
# 2    91902  2018        7889.000000
# 3    91902  2020        4614.000000
# 4    91902  2021        6164.000000
# ..     ...   ...                ...
# 402  92173  2020       10386.500000
# 403  92173  2021        5339.444444
# 404  92173  2022        5495.666667
# 405  92672  2018        3401.000000
# 406  92672  2021        1866.000000
#
# [407 rows x 3 columns]

# %% [markdown]
# #### Prediction Dataframe

# %%
prediction_df = pothole_req_counts.merge(
    traffic_zip_year,
    left_on=['zip','year'],
    right_on=['zip','year'],
    how='inner'
)

prediction_df
# Out:
#        zip  year  pothole_req_count  traffic_count_avg
# 0    91911  2021                  1        5198.833333
# 1    91942  2021                  1        6070.850000
# 2    91942  2022                  1       11713.888889
# 3    91945  2021                  3       11907.156250
# 4    92014  2021                174        3151.100000
# ..     ...   ...                ...                ...
# 135  92154  2021                411        5821.389474
# 136  92154  2022                268        9030.687500
# 137  92173  2020                  1       10386.500000
# 138  92173  2021                105        5339.444444
# 139  92173  2022                 81        5495.666667
#
# [140 rows x 4 columns]

# %%
# ensuring no missing data
prediction_df.isna().sum()
# Out:
# zip                  0
# year                 0
# pothole_req_count    0
# traffic_count_avg    0
# dtype: int64

# %%
# Consulted ChatGPT. Adviced using poisson. Looked at documentation. 

import statsmodels.formula.api as smf

model = smf.poisson(
    formula='pothole_req_count ~ traffic_count_avg',
    data=prediction_df
).fit()

print(model.summary())
# Out:
# ...
#          Current function value: 166.740526
#          Iterations: 35
#                           Poisson Regression Results
# ...
# Dep. Variable:      pothole_req_count   No. Observations:                  140
# Model:                        Poisson   Df Residuals:                      138
# Method:                           MLE   Df Model:                            1
# Date:                Fri, 12 Jun 2026   Pseudo R-squ.:                -0.02534
# Time:                        11:55:58   Log-Likelihood:                -23344.
# converged:                      False   LL-Null:                       -22767.
# Covariance Type:            nonrobust   LLR p-value:                     1.000
# ...
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept             5.0864      0.011    457.206      0.000       5.065       5.108
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    prediction_df[['traffic_count_avg']],
    prediction_df[['pothole_req_count']],
    test_size = 0.2,
    random_state=42
)

# %%
# Used ChatGPT to understand this step

from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, y_train)

prediction = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error

print('\nr2:')
print(r2_score(y_test, prediction))

print('\nMAE:')
print(mean_absolute_error(y_test, prediction))
# Out:
# r2:
# -0.03249548645077649
#
# MAE:
# 235.08044338162412

# %%
prediction_df['pothole_req_count'].describe()
# Out:
# count    140.000000
# mean     188.992857
# std      253.971859
# min        1.000000
# 25%        3.000000
# 50%       20.000000
# 75%      329.750000
# max      936.000000
# Name: pothole_req_count, dtype: float64

# %%
plt.figure(figsize=(7,5))

sns.regplot(
    data=prediction_df,
    x='traffic_count_avg',
    y='pothole_req_count'
)

plt.title('Traffic Volume vs Pothole Requests')
plt.xlabel('Avg Traffic Volume')
plt.ylabel('Pothole Repair Requests')

plt.show()

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#
# [] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# - N/A
#
# [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# - One source of bias is that some buildings will be missing because they are not owned by the city of San Diego County.
#
# [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#
# - The dataset for the city-owned properties is public information that’s readily available. The dataset will be further wrangled to remove any personally identifiable information and only include relevant information.
#
# [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# - Accessing the data of the city-owned properties is public, so data doesn’t include race or gender but it will have a more biased outcome on the lease owners to be a majority of individuals who have wealthier status, by the city, or companies. Other biases can include specific neighborhoods/areas of the district on wealth gaps but not particularly on data itself.
#
# ### B. Data Storage
#
# [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# - Since we’re looking into city-owned properties whether it is public or private that extend from the 1970s to 2026, San Diego county data is constantly up to date on the county website.  But potential cases are the data not having every exact instance of each property as the cost of living in San Diego is increasing. There can also be data leaks for traffic volumes which can lead to misleading numbers or skews within the different north, east, west, and south bound traffic volume numbers.
#
# [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#
# - For traffic volumes, data is pretty vague so there isn’t a way for an individual to request personal information on traffic. As for properties in the city, there are ways to remove personal information but difficulties on removing company or management owned properties that house rentals or subleases might request to remove, this would lead to the individual consulting with company or management in order to request the removal.
#
# [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# - There isn’t a schedule or plan to delete data after it is no longer needed due to constant observation on changes of numbers of potholes increasing or decreasing and older data including costs of lease as a way to continue experimenting.
#
# ### C. Analysis
#
# [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# -  We’re looking at city-owned properties, which would be missing residential properties. To simulate the residential area, we will be looking at properties pertaining to house rentals and subleases. This won’t be able to encapsulate the entirety of a residential areas, but it’s the best case scenario with the public data available to us.
#
# [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# - The city property values dataset looks over all types of buildings within the San Diego county, ranging from different occupation durations. The data will be narrowed down into housing only based on their definition, house rental, and subleasing. We do acknowledge this doesn’t include any houses bought by people, and will include a statement to this. The traffic pattern also overlooks all of San Diego county. Some parts of San Diego will be busier than others, so we will take into account the total count of traffic and the location of traffic.
#
# [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# - Our visualizations and summaries will accurately represent the underlying data because we won’t manipulate the data such that it would be changed or skewed. We also won’t leave any data out so that we only keep data we favor or that favors one side. Nothing will be selective as all relevant data will be included and only columns of unnecessary variables will be left out. We will also evaluate if our datasets are limited and only represent a subset of potholes and leases. To ensure accuracy, we will look for repeated pothole reports, lease inactivity via start dates, and inaccurate reports. We would also like to emphasize that we are predicting correlation rather than causation, as we are only observing datasets instead of doing a field experiment.
#
# [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#
# - We ensured privacy because our data includes no personal information to the lease buyers and the pothole reporters. If there are names, we will remove that column. This is also because there are only some variables we are interested in such as report dates, counts, location, lease types and prices. We also won’t invade on what the lease is for, but rather what type it is. We are also focusing only on the city and part of San Diego rather than specific addresses. This way, we can see trends in different neighborhoods without invading on privacy. This data is public and provided by the city, so we are not exposing any data that isn’t already available.
#
# [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# - The process is well documented and reproducible since we’re using datasets collected by the San Diego County.
#
#
# ### D. Modeling
#
# [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# - Our pothole repair request data directly reflects our target prediction variable (frequency of pothole repair tickets). Reasonably, it may also be used as a proxy for actual pothole prevalence. The dataset includes data from the entirety of San Diego. Of course, factors such as unequal access to requests, repeat requests for the same potholes, and possible false reports are possible confounds for our model that should be addressed by acknowledgement and/or filtering our data. Our city property prices dataset allow us to examine the patterns of price fluctuation throughout the years. Again, this is a direct measure of our target variable (cost of property). It may be argued as a proxy for neighborhood wealth (e.g. the geographical clustering of more expensive properties vs less expensive properties) and be cross-examined with the geographical location of pothole request tickets. Importantly, the dataset includes the entirety of San Diego county and we do not intend to filter by area codes to avoid discriminatory patterns based on potential economic disparities. Our traffic volumes dataset is also a direct reflection of our target variable (traffic density). The dataset includes data from the entirety of San Diego county.
#
# [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# - Considering that our datasets come from the same source and include data from areas across San Diego, we plan to minimize filtering based on geographical location. This is to avoid potentially discriminatory results that arise from selecting areas that are more or less wealthy. We should also plan to investigate potential disparities in data collection (e.g. the population’s access to report forms, data transparency, etc.) in order to consider how we should reasonably (re-)weigh the effects of our variables.
#
# [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# - We defined our metrics by choosing only relevant variables. We chose these by evaluating what factors our hypothesis focuses on and matching them to the columns of our dataset. The variables we chose such as location, lease type, price, date, and price all match our research. We want to evaluate how different parts of San Diego are affected and will match our 3 datasets by date to see if there’s correlations between pothole count, lease price, and traffic count. The lease type also let’s us know if the lease is for residential use. Researching different aspects such as traffic count vs. pothole count also let’s us not assume a conclusion and see if there’s other reasoning of pothole requests.
#
# [] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# - N/A
#
# [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# - We’re specifically looking at city-owned properties because the potholes are on public property, meaning that the city is responsible for fixing them. We would also mention that any houses not owned by the city are not included in the data, mainly because it’s not publicly available, and to protect their personally identifiable information. The traffic patterns are also only taking into account the total number of traffic occurrences based on the location in relation to the houses.
#
# ### E. Deployment
#
# [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#
# - In conjunction with other models or technologies that may measure actual pothole occurrence, we may be able to better ensure that our predictions are 1) accurate, 2) being enacted ethically/responsibly. In other words, if using our model is performing and enacted as intended, pothole occurrence may decrease or be more quickly resolved relative to current rates. If there are incongruencies in this expectation or
# if ethical disparities arise (e.g. lack of care of a particular region of San Diego), an alteration to our model may be required.
#
# [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#
# - Because our hypothesis examines the relationship of pothole frequency, traffic volume, and city property costs in SD country. The analysis could reinforce existing inequalities by directing more attention and repair resources towards higher-property-value neighborhoods while undeserving lower-income areas. We would need to regularly evaluate outputs for geographic or socioeconomic bias. Compare predictions across neighborhoods to ensure lower-cost property are not systematically deprioritized. As well as establish feedback for residents, city officials and stakeholders can report concerns about unfair prioritization or inaccuracy in predictions. We would need to refrain and adjust the model periodically using up to date traffic, lease cost, and repair-request data to reduce bias and improve fairness and accuracy.
#
# [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#
# - Yes there should be a plan to turn off or roll back model if it produces harmful, inaccurate, or biased results in production. Maintaining the ability to temporarily turn off the model by city planners or public infrastructure departments. Previous versions of models and datasets would be stored so we can roll back to earlier and more reliable version if bias is obvious. Wanna maintain accountability, transparency, and flexibility if there is unintended harm or inaccuracies.
#
# [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# - Our model intends to consider the entirety of San Diego county with the data that is available to us. We intend to avoid potentially discriminatory analysis and filtering of data, especially ones based on geographical area. Through writing, we also plan to acknowledge inequities in reporting access (via online forms, county offices, lack of education on reporting, etc.) as well as making a clear distinction between pothole repair requests and actual pothole prevalence. Our model primarily aims to provide predictive power over where potholes may occur more frequently. It does not directly address where repairs are actually being made or planned. Given an extended project, we could utilize technologies/programs that detect actual pothole prevalence + pothole repair and compare that with our model. Using this comparison, we may monitor if our model is subject to overreliance/overgeneralization leading to unequal care for parts of San Diego county (e.g. if repairs are only made in predicted “high-pothole request” areas while predicted “low-pothole request” areas never see repairs).

# %% [markdown]
# ## Discusison and Conclusion
#
# Our group wanted to determine if there was a relationship between the pothole repair request and the city property cost within San Diego County, and if it could be used to predict the frequency of pothole repair requests. Based on research, we hypothesized that there’s a strong correlation between the number of pothole repair requests, traffic volume, and city property costs in San Diego County. Specifically, we predict that higher traffic volumes and higher property costs correlate with a greater frequency of pothole requests. We explored and combined datasets related to traffic volume, San Diego County’s property costs, and pothole repair requests by statistical and geographical analyses. When combining the datasets, the timeframes were limited to between 2017 and 2022.
#
# Based on the results, the linear regression analysis between the pothole repair request and the property cost provided little to no support for a direct relationship. The adjusted R-squared value was -0.250, which indicates that there’s no variation in the pothole requests. The negative adjusted R-squared value can be explained by using fewer than eight observations.
#
# The choropleth analyses were able to provide which of the zip codes had higher traffic volumes, leading to higher repair requests.  These zip codes would include 92126, 92128, 92111, 92115, and 92117.  Because of this, the choropleth would highlight that the traffic activity is only found in specific areas of San Diego, and several of the zip codes showed signs of high traffic incidents.  This gives good support for the idea that the increase in traffic contributes to the degradation of roadways and the formation of potholes.  Though the relationship between the several zip codes is not consistent, this would suggest that the volume of traffic is not the sole contributor, nor the only reason to explain the amount of pothole repair requests.
#
# The importance of this data is to showcase just how complex predicting pothole formations can be.  Though previous research shows that pothole formations are actually influenced by multiple factors, some of which include: weather, condition of pavement, drainage quality, and history of the area's maintenance.  Of course, high traffic will contribute to the wear of roads; however, neither traffic load nor property costs by themselves can justify the multiple counts of repair requests in San Diego.  The lack of a definitive statistic may suggest that more in-depth factors in terms of contributing to pothole formations were not seen in the analysis.
# When analyzing the results, several limitations should be considered. The first one being that city property leases do not cover all bases of property located within San Diego County.  Because of this, the results may not accurately represent local property values or the value of economics.  Second would be the repair requests, in the sense that they serve as a temporary fix for the actual pothole frequency.  The reporting statistic will also vary depending on the neighborhood due to the difference in population, awareness of city services, and, most importantly, the effort to actually submit requests.  On top of that, reports of the same pothole may also be included in the dataset.  The third thing is the limited number of observations that are actually available for the analysis of property costs, which heavily reduces the statistics of the model and, in turn, limits the ability to identify important and meaningful relationships.  Ultimately, our study was able to use historical data taken from 2017 to 2022, and did not include changes in infrastructure, weather conditions, and traffic patterns.
#
# In the future, new analyses may be able to improve on this by incorporating additional data and variables that are known to influence roadway conditions specifically.  These can be things such as the history of pavement, precipitation, classification of roads, the scheduling of maintenance duties, and accurate measures of pavement quality.  Furthermore, expanding the dataset so that it includes more years of observations and a better understanding of property value information would also enhance the reliability of future models.  A longevity analysis that tracks neighborhoods over a certain period of time may be able to provide more damning evidence regarding factors that contribute to pothole formations and repair requests.  Though our findings and data do not fully support a strong relationship between the costs and requests.  This suggests that the volume of traffic may play a role and heavily affect the importance when considering the multiple factors when it comes to the environment and infrastructure when predicting the roadway maintenance in San Diego.
